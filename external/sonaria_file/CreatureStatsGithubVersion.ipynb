# %% [markdown]
# Координаты лавы для universal_sonaria_bot.lua: X=1973, Y=238, Z=1616 (актуально).

# %% [markdown]
# # WARNING
#
# The preview for this file in Github is broken. **DO NOT copy and paste from the preview.** Read the README for further instructions.

# %% [markdown]
# # Extract, Transform

# %%
import requests
import pandas as pd
import numpy as np
import gc

willStore = False
lines = []

for line in requests.get('https://creatures-of-sonaria-official.fandom.com/wiki/Module:CreatureData/data').text.split('\n'):
    line = line.strip()
    if line == '' or '<meta' in line:
        willStore = False
    if willStore:
        lines.append(line)
    if 'p.creatureStats' in line:
        willStore = True

strings = ''.join(lines).replace('&#039;','').replace('&quot;','"').replace('&lt;','').replace('&gt;','').split('\t')[:-1]

columns = ['name']

for string in strings:
    if '}' in string:
        break
    if '{' not in string:
        columns.append(string[2:string.index(']')-1])

data = [[]]
index = 0

for string in strings:
    #precautionary data cleaning
    string = string.replace(').','),').replace('  ',' ')

    if '[[' in string:
        string = string[:string.index('[[')] + string[string.rindex(']]')+2:]
    if '}' in string:
        index += 1
        data.append([])
    if '"' in string:
        temp = string[string.index('"')+1:string.rindex('"')].strip()
        if temp.endswith('min'):
            temp = temp[:temp.index('min')-1]
        if temp.isdecimal():
            temp = int(temp)
        elif temp.replace('.','').isdecimal():
            temp = float(temp)
        elif temp == 'N/A':
            temp = np.nan
        data[index].append(temp)
    else:
        data[index].append(string[string.index('/')-2:string.rindex(',')])

df = pd.DataFrame(data, columns=columns)

if all(df['name'] == df['common']):
    df.drop(columns='common', inplace=True)
df.drop(columns=[col for col in df.columns if df[col].nunique(dropna=False) == 1], inplace=True) #drops columns with the same value for every creature (like hungerDrain)

eWeightList = []
eDPSList = []
eHPList = []
for i in range(df.shape[0]):
    eWeight = 1
    eDPS = 1
    eHP = 1
    if isinstance(df.at[i, 'activated'], str):
        if 'Fortify' in df.at[i, 'activated']:
            eWeight += 0.05
        if 'Harden' in df.at[i, 'activated']:
            eWeight += 0.25
        if 'Adrenaline' in df.at[i, 'activated']:
            eDPS += 0.2
        if 'Unbridled Rage' in df.at[i, 'activated']:
            eDPS += 0.3
        if 'Wardens Rage' in df.at[i, 'activated']:
            eDPS += 5.625
        if 'Cause Fear' in df.at[i, 'activated']:
            eHP += 1
    if isinstance(df.at[i, 'passive'], str) and 'Berserk' in df.at[i, 'passive']:
        eDPS += 0.2
    eWeight *= df.at[i, 'weight']
    eWeightList.append(eWeight)
    eDPS *= df.at[i, 'damage'] * (1 + eWeight / 50000) / (2 * df.at[i, 'biteCooldown'])
    eDPSList.append(eDPS)
    eHP *= df.at[i, 'health'] / (1 + 50000 / eWeight)
    eHPList.append(eHP)
df['effectiveWeight'] = eWeightList
df['effectiveDPS'] = eDPSList
df['effectiveHP'] = eHPList
df['effectivePower'] = df['effectiveDPS'] * df['effectiveHP']

def flySprintMultiplier(fsm: float) -> float:
    if np.isnan(fsm):
        return 1
    return 1 + fsm
def ambush(a: float) -> float:
    if np.isnan(a):
        return 1
    return a
def agileSwimmer(passive) -> float:
    if isinstance(passive, str) and 'Agile Swimmer' in passive:
        return 1.75
    return 1
df['flySprintSpeed'] = df['flySpeed'] * df['flySprintMultiplier'].apply(flySprintMultiplier)
df['swimSprintSpeed'] = df['sprintSpeed'] * df['passive'].apply(agileSwimmer)
df['ambushSpeed'] = df['sprintSpeed'] * df['ambush'].apply(ambush)
df['swimAmbushSpeed'] = df['swimSprintSpeed'] * df['ambush'].apply(ambush)
df['effectiveHPRegen'] = df['effectiveHP'] * df['healthRegen']

def wardensRage(string):
    if isinstance(string, str):
        return string.replace('Wardens Rage', "Warden's Rage")
    return string
df['activated'] = df['activated'].apply(wardensRage)

def split(string) -> list[str]:
    if not isinstance(string, str):
        return []
    list1 = string.split(',')
    for string1 in list1:
        string1 = string1.strip()
    return list1
passives = df['passive'].apply(split)
activateds = df['activated'].apply(split)
passiveDF = pd.merge(df['name'], passives, left_index=True, right_index=True).explode('passive', ignore_index=True)
activatedDF = pd.merge(df['name'], activateds, left_index=True, right_index=True).explode('activated', ignore_index=True)

for col in passiveDF.columns:
    passiveDF[col] = passiveDF[col].str.strip()
for col in activatedDF.columns:
    activatedDF[col] = activatedDF[col].str.strip()

spreadsheetDF = df.copy()
df.drop(columns=['passive', 'activated'], inplace=True)

del willStore, lines, strings, line, columns, data, index, temp, string, eWeightList, eDPSList, eHPList, eWeight, eDPS, eHP, i, flySprintMultiplier, ambush, agileSwimmer, wardensRage, passives, activateds
#keep split
gc.collect()
# Out:
# 76

# %% [markdown]
# # Verify

# %%
#This code produces 6 different outputs: Suspicious flyers, unique passive abilities, unique activated abilities,
#miscategorized abilities, rows in spreadsheetDF with trailing commas in passive or activated,
#and number of missing values in each column.
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 500)

print('\nSuspicious flyers:')
for i in range(df.shape[0]):
    if not np.isnan(df.at[i, 'flySpeed']):
        if np.isnan(df.at[i, 'flySprintMultiplier']) or np.isnan(df.at[i, 'glideStaminaRegen']) or np.isnan(df.at[i, 'takeoffMultiplier']):
            print(df.loc[i, ['name', 'flySpeed', 'flySprintMultiplier', 'glideStaminaRegen', 'takeoffMultiplier']])

print('\nUnique passive abilities:')
print(np.sort(passiveDF['passive'].fillna('').unique()))

print('\nUnique activated abilities:')
print(np.sort(activatedDF['activated'].fillna('').unique()))

print('\nMiscategorized abilities:')
print(pd.merge(passiveDF, activatedDF, left_on='passive', right_on='activated')['passive'].fillna('').unique())

print('\nTrailing commas:')
spreadsheetDF.reset_index(drop=True, inplace=True)
for i in range(spreadsheetDF.shape[0]):
    if isinstance(spreadsheetDF.at[i, 'passive'], str) and spreadsheetDF.at[i, 'passive'].strip().endswith(','):
        print(spreadsheetDF.loc[i, ['name', 'passive']])
    if isinstance(spreadsheetDF.at[i, 'activated'], str) and spreadsheetDF.at[i, 'activated'].strip().endswith(','):
        print(spreadsheetDF.loc[i, ['name', 'activated']])

print('\nNumber of missing values in each column:')
df.isna().sum()
# Out:
# Suspicious flyers:
# name                   Exotide
# flySpeed                  48.0
# flySprintMultiplier        NaN
# glideStaminaRegen          1.0
# takeoffMultiplier         15.0
# Name: 103, dtype: object
# name                   Umbraxi
# flySpeed                  29.0
# flySprintMultiplier        0.3
# glideStaminaRegen          NaN
# takeoffMultiplier         25.0
# Name: 352, dtype: object
#
# Unique passive abilities:
# ['Agile Swimmer' 'Berserk' 'Bleed Attack (-0.5)' 'Bleed Attack (-1)'
#  'Bleed Attack (-1.5)' 'Bleed Attack (-2)' 'Bleed Attack (-3)'
#  'Bleed Attack (-3.5)' 'Bleed Attack (0.5)' 'Bleed Attack (1)'
#  'Bleed Attack (1.5)' 'Bleed Attack (10)' 'Bleed Attack (15)'
#  'Bleed Attack (2)' 'Bleed Attack (2.5)' 'Bleed Attack (20)'
#  'Bleed Attack (3)' 'Bleed Attack (3.5)' 'Bleed Attack (4)'
#  'Bleed Attack (4.5)' 'Bleed Attack (5)' 'Bleed Attack (5.5)'
#  'Bleed Attack (6)' 'Bleed Attack (8)' 'Bleed Attack (9)'
#  'Block Bleed (-0.10)' 'Block Bleed (-0.15)' 'Block Bleed (-0.20)'
#  'Block Bleed (-0.25)' 'Block Bleed (-0.30)' 'Block Bleed (-0.40)'
#  'Block Bleed (-0.45)' 'Block Bleed (-1.0)' 'Block Bleed (0.05)'
#  'Block Bleed (0.1)' 'Block Bleed (0.10)' 'Block Bleed (0.15)'
#  'Block Bleed (0.2)' 'Block Bleed (0.20)' 'Block Bleed (0.25)'
#  'Block Bleed (0.3)' 'Block Bleed (0.30)' 'Block Bleed (0.35)'
#  'Block Bleed (0.4)' 'Block Bleed (0.40)' 'Block Bleed (0.45)'
#  'Block Bleed (0.5)' 'Block Bleed (0.50)' 'Block Bleed (0.55)'
#  'Block Bleed (0.6)' 'Block Bleed (0.60)' 'Block Bleed (0.65)'
#  'Block Bleed (0.7)' 'Block Bleed (0.70)' 'Block Bleed (0.75)'
#  'Block Bleed (0.8)' 'Block Bleed (0.80)' 'Block Bleed (0.85)'
#  'Block Bleed (0.9)' 'Block Bleed (0.90)' 'Block Bleed (1.00)'
#  'Block Burn (-0.1)' 'Block Burn (-0.10)' 'Block Burn (-0.15)'
#  'Block Burn (-0.2)' 'Block Burn (-0.20)' 'Block Burn (-0.25)'
#  'Block Burn (-0.3)' 'Block Burn (-0.30)' 'Block Burn (-0.35)'
#  'Block Burn (-0.4)' 'Block Burn (-0.50)' 'Block Burn (0.2)'
#  'Block Burn (0.20)' 'Block Burn (0.25)' 'Block Burn (0.3)'
#  'Block Burn (0.30)' 'Block Burn (0.35)' 'Block Burn (0.4)'
#  'Block Burn (0.40)' 'Block Burn (0.45)' 'Block Burn (0.5)'
#  'Block Burn (0.50)' 'Block Burn (0.55)' 'Block Burn (0.60)'
#  'Block Burn (0.75)' 'Block Burn (0.80)' 'Block Burn (0.85)'
#  'Block Burn (0.90)' 'Block Burn (1.00)' 'Block Disease (-0.20)'
#  'Block Disease (-0.25)' 'Block Disease (0.2)' 'Block Disease (0.3)'
#  'Block Disease (0.30)' 'Block Disease (0.4)' 'Block Disease (0.50)'
#  'Block Disease (0.55)' 'Block Disease (0.60)' 'Block Disease (0.65)'
#  'Block Disease (0.70)' 'Block Disease (0.80)' 'Block Disease (1.00)'
#  'Block Frostbite (-0.20)' 'Block Frostbite (-0.25)'
#  'Block Frostbite (-0.45)' 'Block Frostbite (0.10)'
#  'Block Frostbite (0.20)' 'Block Frostbite (0.25)' 'Block Frostbite (0.3)'
#  'Block Frostbite (0.30)' 'Block Frostbite (0.35)' 'Block Frostbite (0.4)'
#  'Block Frostbite (0.40)' 'Block Frostbite (0.45)' 'Block Frostbite (0.5)'
#  'Block Frostbite (0.50)' 'Block Frostbite (0.55)'
#  'Block Frostbite (0.60)' 'Block Frostbite (0.65)'
#  'Block Frostbite (0.75)' 'Block Frostbite (0.85)' 'Block Frostbite (0.9)'
#  'Block Frostbite (1.0)' 'Block Frostbite (1.00)' 'Block Injury (-0.10)'
#  'Block Injury (-0.15)' 'Block Injury (-0.25)' 'Block Injury (-0.30)'
#  'Block Injury (-0.35)' 'Block Injury (0.10)' 'Block Injury (0.15)'
#  'Block Injury (0.2)' 'Block Injury (0.20)' 'Block Injury (0.25)'
#  'Block Injury (0.3)' 'Block Injury (0.30)' 'Block Injury (0.35)'
#  'Block Injury (0.4)' 'Block Injury (0.40)' 'Block Injury (0.45)'
#  'Block Injury (0.5)' 'Block Injury (0.50)' 'Block Injury (0.55)'
#  'Block Injury (0.65)' 'Block Injury (0.70)' 'Block Injury (0.75)'
#  'Block Injury (0.80)' 'Block Injury (0.85)' 'Block Injury (1.00)'
#  'Block Necropoison (0.25)' 'Block Necropoison (0.30)'
#  'Block Necropoison (0.35)' 'Block Necropoison (0.4)'
#  'Block Necropoison (0.40)' 'Block Necropoison (0.45)'
#  'Block Necropoison (0.5)' 'Block Necropoison (0.50)'
#  'Block Necropoison (0.65)' 'Block Necropoison (0.75)'
#  'Block Necropoison (0.85)' 'Block Necropoison (0.90)'
#  'Block Necropoison (1.00)' 'Block Poison (-0.15)' 'Block Poison (-0.2)'
#  'Block Poison (-0.25)' 'Block Poison (-0.30)' 'Block Poison (-0.75)'
#  'Block Poison (0.15)' 'Block Poison (0.2)' 'Block Poison (0.20)'
#  'Block Poison (0.25)' 'Block Poison (0.3)' 'Block Poison (0.30)'
#  'Block Poison (0.35)' 'Block Poison (0.4)' 'Block Poison (0.40)'
#  'Block Poison (0.45)' 'Block Poison (0.5)' 'Block Poison (0.50)'
#  'Block Poison (0.55)' 'Block Poison (0.6)' 'Block Poison (0.60)'
#  'Block Poison (0.65)' 'Block Poison (0.7)' 'Block Poison (0.70)'
#  'Block Poison (0.75)' 'Block Poison (0.8)' 'Block Poison (0.80)'
#  'Block Poison (0.85)' 'Block Poison (1.0)' 'Block Poison (1.00)'
#  'Breath Resistance (0.35)' 'Breath Resistance (0.40)'
#  'Breath Resistance (0.5)' 'Breath Resistance (0.50)'
#  'Breath Resistance (0.55)' 'Breath Resistance (0.60)'
#  'Breath Resistance (0.75)' 'Breath Resistance (0.9)'
#  'Breath Resistance (0.90)' 'Broodwatcher' 'Burn Attack (-1)'
#  'Burn Attack (-3.5)' 'Burn Attack (-4)' 'Burn Attack (0.5)'
#  'Burn Attack (1)' 'Burn Attack (1.5)' 'Burn Attack (2)'
#  'Burn Attack (2.5)' 'Burn Attack (3)' 'Burn Attack (3.5)' 'Channeling'
#  'Charge (Crush)' 'Charge (Gore)' 'Charge (Launch)' 'Charge (Power)'
#  'Charge (Throw)' 'Climber' 'Corrosion Attack (-0.5)'
#  'Corrosion Attack (-1)' 'Corrosion Attack (0.5)' 'Corrosion Attack (1)'
#  'Corrosion Attack (1.25)' 'Corrosion Attack (1.5)' 'Corrosion Attack (2)'
#  'Corrosion Attack (4.5)' 'Defensive Bleed (-2)' 'Defensive Bleed (0.5)'
#  'Defensive Bleed (1)' 'Defensive Bleed (1.5)' 'Defensive Bleed (2)'
#  'Defensive Bleed (2.5)' 'Defensive Bleed (3)' 'Defensive Bleed (4)'
#  'Defensive Bleed (5)' 'Defensive Burn (-1)' 'Defensive Burn (0.5)'
#  'Defensive Burn (1)' 'Defensive Burn (1.5)' 'Defensive Burn (2)'
#  'Defensive Burn (2.5)' 'Defensive Burn (3)' 'Defensive Burn (3.5)'
#  'Defensive Burn (4)' 'Defensive Burn (5)' 'Defensive Corrosion (0.5)'
#  'Defensive Corrosion (1)' 'Defensive Corrosion (1.5)'
#  'Defensive Corrosion (2)' 'Defensive Corrosion (3)'
#  'Defensive Corrosion (3.5)' 'Defensive Disease (0.5)'
#  'Defensive Disease (1.5)' 'Defensive Disease (2)'
#  'Defensive Disease (2.5)' 'Defensive Disease (3)'
#  'Defensive Disease (3.5)' 'Defensive Disease (4)'
#  'Defensive Disease (4.5)' 'Defensive Disease (5)'
#  'Defensive Frostbite (-1)' 'Defensive Frostbite (0.5)'
#  'Defensive Frostbite (1)' 'Defensive Frostbite (1.5)'
#  'Defensive Frostbite (2)' 'Defensive Frostbite (3.5)'
#  'Defensive Frostbite (5)' 'Defensive Injury (0.5)' 'Defensive Injury (1)'
#  'Defensive Injury (1.5)' 'Defensive Injury (2)' 'Defensive Injury (2.5)'
#  'Defensive Necropoison (-1)' 'Defensive Necropoison (0.5)'
#  'Defensive Necropoison (1)' 'Defensive Necropoison (1.5)'
#  'Defensive Necropoison (2)' 'Defensive Necropoison (2.5)'
#  'Defensive Necropoison (3)' 'Defensive Necropoison (3.5)'
#  'Defensive Paralyze (1)' 'Defensive Paralyze (2)'
#  'Defensive Poison (-1.5)' 'Defensive Poison (0.5)' 'Defensive Poison (1)'
#  'Defensive Poison (1.5)' 'Defensive Poison (2)' 'Defensive Poison (2.5)'
#  'Defensive Poison (3)' 'Defensive Poison (3.5)' 'Defensive Poison (4)'
#  'Defensive Poison (6)' 'Defensive Poison (7.5)' 'Disease Attack (-0.5)'
#  'Disease Attack (-3)' 'Disease Attack (-4)' 'Disease Attack (1)'
#  'Disease Attack (1.5)' 'Disease Attack (1.75)' 'Disease Attack (2)'
#  'Disease Attack (2.5)' 'Disease Attack (3)' 'Disease Attack (3.5)'
#  'Disease Attack (4)' 'Disease Attack (4.5)' 'Disease Attack (6)'
#  'Disease Attack (8)' 'Diver (10)' 'Diver (12)' 'Diver (15)' 'Diver (18)'
#  'Diver (2)' 'Diver (3)' 'Diver (4)' 'Diver (5)' 'Diver (6)' 'Diver (7)'
#  'Diver (8)' 'Egg Stealer' 'First Strike (0.10)' 'First Strike (0.15)'
#  'First Strike (0.2)' 'First Strike (0.20)' 'First Strike (0.25)'
#  'First Strike (0.28)' 'First Strike (0.30)' 'First Strike (0.4)'
#  'First Strike (0.40)' 'First Strike (0.50)' 'First Strike (0.66)'
#  'Frostbite Attack (-0.5)' 'Frostbite Attack (-1)' 'Frostbite Attack (-2)'
#  'Frostbite Attack (-5)' 'Frostbite Attack (0.5)' 'Frostbite Attack (1)'
#  'Frostbite Attack (1.5)' 'Frostbite Attack (2)' 'Frostbite Attack (2.5)'
#  'Frostbite Attack (3)' 'Frostbite Attack (3.5)' 'Frostbite Attack (4)'
#  'Frosty' 'Guilt' 'Healing Step (1)' 'Healing Step (1.5)'
#  'Healing Step (2)' 'Healing Step (3)' 'Hunker (30)' 'Hunker (50)'
#  'Hunker (55)' 'Hunker (60)' 'Hunker (65)' 'Hunker (70)' 'Hunker (75)'
#  'Hunker (80)' 'Injury Attack (-0.5)' 'Injury Attack (-2)'
#  'Injury Attack (-3.5)' 'Injury Attack (0.5)' 'Injury Attack (0.75)'
#  'Injury Attack (1)' 'Injury Attack (1.25)' 'Injury Attack (1.5)'
#  'Injury Attack (2)' 'Injury Attack (2.5)' 'Injury Attack (3)'
#  'Injury Attack (3.5)' 'Injury Attack (4)' 'Injury Attack (4.25)'
#  'Injury Attack (5)' 'Injury Attack (6)' 'Injury Attack (8)'
#  'Iron Stomach' 'Keen Observer' 'Necropoison Attack (-0.5)'
#  'Necropoison Attack (0.5)' 'Necropoison Attack (1)'
#  'Necropoison Attack (1.5)' 'Necropoison Attack (2)'
#  'Necropoison Attack (3)' 'Pack Healer' 'Poison Attack (-0.5)'
#  'Poison Attack (-1)' 'Poison Attack (-2)' 'Poison Attack (-3)'
#  'Poison Attack (-4)' 'Poison Attack (0.5)' 'Poison Attack (1)'
#  'Poison Attack (1.5)' 'Poison Attack (2)' 'Poison Attack (2.5)'
#  'Poison Attack (3)' 'Poison Attack (4)' 'Poison Attack (4.5)'
#  'Quick Recovery' 'Raider' 'Serrated Teeth' 'Soft Landing (0.58)'
#  'Soft Landing (0.6)' 'Soft Landing (0.60)' 'Soft Landing (0.65)'
#  'Soft Landing (0.7)' 'Soft Landing (0.70)' 'Soft Landing (0.72)'
#  'Soft Landing (0.73)' 'Soft Landing (0.75)' 'Soft Landing (0.77)'
#  'Soft Landing (0.78)' 'Soft Landing (0.8)' 'Soft Landing (0.84)'
#  'Soft Landing (0.85)' 'Soft Landing (0.86)' 'Soft Landing (0.88)'
#  'Soft Landing (0.89)' 'Soft Landing (0.9)' 'Soft Landing (0.92)'
#  'Sonic Wings' 'Sticky Fur' 'Strength In Numbers' 'Strength in Numbers'
#  'Toxic Trail (0.15)' 'Toxic Trail (0.20)' 'Toxic Trail (0.25)'
#  'Toxic Trail (0.35)' 'Toxic Trail (0.40)' 'Toxic Trail (0.45)'
#  'Toxic Trail (0.5)' 'Toxic Trail (0.50)' 'Toxic Trail (0.6)'
#  'Toxic Trail (0.60)' 'Toxic Trail (0.65)' 'Unbreakable' 'Volcanic'
#  "Warden's Resistance" 'Will To Live' 'Wing Shredder (1)'
#  'Wing Shredder (1.2)' 'Wing Shredder (2)' 'Wing Shredder (3)'
#  'Wing Shredder (5)']
#
# Unique activated abilities:
# ['' 'Adrenaline' 'Area Food Restore' 'Area Water Restore' 'Burrower (1)'
#  'Burrower (2)' 'Burrower (3)' 'Burrower (4)' 'Cause Fear'
#  'Change Weather' 'Cursed Sigil (10)' 'Cursed Sigil (3)'
#  'Cursed Sigil (4)' 'Cursed Sigil (5)' 'Cursed Sigil (6)'
#  'Cursed Sigil (7)' 'Cursed Sigil (8)' 'Damage Link' 'Dazzling Flash'
#  'Drowsy Area' 'Earthquake' 'Egg Stealer' 'Escape Area' 'Fortify'
#  'Frost Nova (100)' 'Frost Nova (200)' 'Frost Nova (50)' 'Frost Nova (75)'
#  'Frost Snare' 'Gale' 'Grab' 'Harden' 'Heal Aura (0.5)' 'Heal Aura (1)'
#  'Heal Aura (1.5)' 'Heal Aura (2)' 'Heal Aura (2.5)' 'Heal Aura (3)'
#  'Healing Hunter (100)' 'Healing Hunter (140)' 'Healing Hunter (160)'
#  'Healing Hunter (170)' 'Healing Hunter (50)' 'Healing Hunter (60)'
#  'Healing Hunter (65)' 'Healing Hunter (70)' 'Healing Hunter (75)'
#  'Healing Hunter (80)' 'Healing Pulse' 'Hunters Curse' 'Invisibility'
#  'Latch' 'Latch (0)' 'Latch (1)' 'Latch (2)' 'Life Leech (0.20)'
#  'Life Leech (0.25)' 'Life Leech (0.3)' 'Life Leech (0.30)'
#  'Life Leech (0.40)' 'Life Leech (0.50)' 'Life Leech (0.55)'
#  'Life Leech (0.60)' 'Lure' 'Mud Pile' 'Poison Area' 'Radiation (0.25)'
#  'Radiation (0.5)' 'Radiation (0.75)' 'Radiation (3)' 'Reflect' 'Rewind'
#  'Self-Destruct' 'Shadow Barrage (3)' 'Shadow Barrage (5)' 'Shock Area'
#  'Snow Shield' 'Speed Blitz' 'Speed Steal' 'Spite (-3.00)' 'Spite (-5.0)'
#  'Spite (0.05)' 'Spite (0.10)' 'Spite (0.16)' 'Spite (0.20)'
#  'Spite (0.25)' 'Spite (0.30)' 'Spite (0.35)' 'Spite (0.40)' 'Spite (0.5)'
#  'Spite (0.50)' 'Spite (0.55)' 'Spite (0.60)' 'Spite (0.75)'
#  'Spite (1.00)' 'Spite (2.00)' 'Stamina Puddle' 'Sticky Trap' 'Tail Drop'
#  'Thorn Trap' 'Totem (Poison)' 'Toxic Trap' 'Unbridled Rage'
#  "Warden's Rage" 'Yolk Bomb (BadOmen)' 'Yolk Bomb (BlurredVision)'
#  'Yolk Bomb (Burn)' 'Yolk Bomb (Confusion)' 'Yolk Bomb (Corrosion)'
#  'Yolk Bomb (Deep Wounds)' 'Yolk Bomb (Drowsy)' 'Yolk Bomb (Flowering)'
#  'Yolk Bomb (Fortify)' 'Yolk Bomb (Frostbite)' 'Yolk Bomb (Healing Pulse)'
#  'Yolk Bomb (Necropoison)' 'Yolk Bomb (Stamina Boost)']
#
# Miscategorized abilities:
# ['Egg Stealer']
#
# Trailing commas:
#
# Number of missing values in each column:
# name                     0
# ambush                 237
# appetite                 0
# beachSpeed             373
# biteCooldown             0
# bloodColor               0
# bloodTexture             0
# breath                 265
# type                     0
# damage                   0
# dartPower              302
# dartStamina            302
# diet                     0
# flySpeed               263
# flySprintMultiplier    264
# glideStaminaRegen      264
# growthTime               0
# health                   0
# healthRegen              0
# jumpAge                390
# jumpPower              280
# jumpStamina            280
# moistureTime           343
# nightvision              0
# oxygenTime              68
# sprintSpeed              0
# stamina                  0
# stamRegen                0
# damage2                361
# takeoffMultiplier      263
# thirstDrain              0
# tier                     0
# turn                     0
# walkAndSwimSpeed         0
# weight                   0
# class                    0
# conceptBy                0
# dateAdded                0
# storedPrice              0
# imageLink                0
# legacyName               0
# loreName                 0
# effectiveWeight          0
# effectiveDPS             0
# effectiveHP              0
# effectivePower           0
# flySprintSpeed         263
# swimSprintSpeed          0
# ambushSpeed              0
# swimAmbushSpeed          0
# effectiveHPRegen         0
# dtype: int64

# %% [markdown]
# # Clean

# %% [markdown]
# Checklist:
# * Pernirex, Shro, and Tsugae have "Egg Stealer" listed in passive abilities instead of activated abilities. ✅
# * Some of the "Breath Resistance", "Block (Status)", "First Strike", "Toxic Trail", "Life Leech", and "Spite" abilities display as 0.1 instead of 0.10, 0.2 instead of 0.20, and so on up to 1.0 instead of 1.00. ✅
#
# Note: missing numbers will not be addressed in this program due to requiring in-game testing. Any determinations of the missing numbers should be reported [here](https://creatures-of-sonaria-official.fandom.com/f/p/4400000000000310169).

# %%
spreadsheetDF.set_index('name', drop=False, inplace=True)

#Egg Stealer fix
for name in ('Pernirex', 'Shro', 'Tsugae'):
    spreadsheetDF.at[name, 'activated'] = spreadsheetDF.at[name, 'activated'] + ', Egg Stealer'
    spreadsheetDF.at[name, 'passive'] = spreadsheetDF.at[name, 'passive'].replace('Egg Stealer', '').replace(', , ', ', ')
    if spreadsheetDF.at[name, 'passive'].startswith(','):
        spreadsheetDF.at[name, 'passive'] = spreadsheetDF.at[name, 'passive'][1:].strip()
    elif spreadsheetDF.at[name, 'passive'].strip().endswith(','):
        spreadsheetDF.at[name, 'passive'] = spreadsheetDF.at[name, 'passive'].strip()[:-1]

#Remake passiveDF & activatedDF
passives = spreadsheetDF['passive'].apply(split)
activateds = spreadsheetDF['activated'].apply(split)
passiveDF = pd.merge(spreadsheetDF['name'], passives, left_index=True, right_index=True).explode('passive', ignore_index=True)
activatedDF = pd.merge(spreadsheetDF['name'], activateds, left_index=True, right_index=True).explode('activated', ignore_index=True)

for col in passiveDF.columns:
    passiveDF[col] = passiveDF[col].str.strip()
for col in activatedDF.columns:
    activatedDF[col] = activatedDF[col].str.strip()

#Decimal formatting fix
def passiveDecimalFormattingFix(string):
    if isinstance(string, str) and 'Attack' not in string and 'Defensive' not in string:
        if '(0.' in string and string.index(')') - string.index('(') != 5:
            return string.replace(')','0)')
        if '(-0.' in string and string.index(')') - string.index('(') != 6:
            return string.replace(')','0)')
        return string.replace('.0)','.00)')
    return string
def activatedDecimalFormattingFix(string):
    if isinstance(string, str) and ('Life Leech' in string or 'Spite' in string):
        if '(0.' in string and string.index(')') - string.index('(') != 5:
            return string.replace(')','0)')
        return string.replace('.0)','.00)')
    return string
passiveDF['passive'] = passiveDF['passive'].apply(passiveDecimalFormattingFix)
activatedDF['activated'] = activatedDF['activated'].apply(activatedDecimalFormattingFix)

del passives, activateds, passiveDecimalFormattingFix, activatedDecimalFormattingFix
gc.collect()
# Out:
# 76

# %% [markdown]
# # Load

# %% [markdown]
# The first 3 tsv files are for importing into a database (although I haven't tested them in a database management system aside from LibreBase which did not work). The last one is for opening with Google Sheets or Microsoft Excel.

# %%
df.to_csv('CreatureData.tsv', sep='\t', na_rep='-1', index=False)
passiveDF.to_csv('CreaturePassive.tsv', sep='\t', index=False)
activatedDF.to_csv('CreatureActivated.tsv', sep='\t', index=False)
spreadsheetDF.to_csv('CreatureDataSpreadsheet.tsv', sep='\t', index=False)
